# %%
# Import dependencies
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset
# Load the dataset
dataset_path = "student-por.csv"
df = pd.read_csv(dataset_path)

# %%
# Dataframe sample
df.sample(6)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob
# 133     GP   F   15       U     GT3       T     1     1   at_home    other  \
# 38      GP   F   15       R     GT3       T     3     4  services   health
# 293     GP   F   18       U     LE3       T     1     1     other  at_home
# 360     GP   F   18       U     GT3       T     3     3   at_home    other
# 338     GP   F   17       R     LE3       T     3     1  services    other
# 194     GP   M   16       U     GT3       T     4     3   teacher    other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 133  ...      4        3      3     1     2      4        6  11  12  13
# 38   ...      4        3      2     1     1      5        2  11  12  12
# 293  ...      4        4      3     2     3      3        4  11  12  14
# 360  ...      4        1      4     1     1      3        8  11  12  14
# 338  ...      3        1      2     1     1      3        0  18  19  19
# ...

# %%
# Display the columns and their data types
print("Columns and Data Types:")
print(df.dtypes)
# Out:
# Columns and Data Types:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# Checking for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['age']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Student Ages')

# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['sex']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Student Sex')

# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['famsize']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('Distribution of Student Family Size')
# Display the plot
plt.show()

print ("Where GT3 = greater than three")
print("Where LE3 = less or equal to three")
# Out:
# Where GT3 = greater than three
# Where LE3 = less or equal to three

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['internet']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('Availability of Internet to Student')
# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['health']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('Student Health from 1 - very bad to 5 - very good')
# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['G1']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('first period grade (numeric: from 0 to 20)')

# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['G2']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('second period grade (numeric: from 0 to 20)')

# Display the plot
plt.show()

# %%
# Set style for seaborn
sns.set_style("whitegrid")

# Extract the ages column from the DataFrame
ages = df['G2']

# Calculate the frequency of each age
age_counts = ages.value_counts()

# Sort the ages in ascending order
age_counts = age_counts.sort_index()

# Plotting the bar graph
plt.bar(age_counts.index, age_counts.values)

# Add labels and title
plt.xlabel('Size')
plt.ylabel('Count')
plt.title('final grade (numeric: from 0 to 20, output target)')

# Display the plot
plt.show()

# %%
# Select the categorical columns to be encoded
categorical_cols = ['health', 'G1', 'G2', 'G3']

# Identify non-numeric columns
non_numeric_cols = df.select_dtypes(exclude=[np.number]).columns

# Drop non-numeric columns from the DataFrame
df_numeric = df.drop(non_numeric_cols, axis=1)

# Calculate the correlation matrix on the numeric DataFrame
correlation_matrix = df_numeric.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# Add labels and title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()
